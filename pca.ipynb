# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\varad\OneDrive\Desktop\datasets\AndreNg\unsupervised learning\PCA\toy_dataset.csv')

# %%
df.shape
# Out:
# (500, 1000)

# %%
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  27.422157 -29.662712 -23.297163 -15.161935   0.345581   3.706750
# 1   3.489482 -19.153551 -14.636424  14.688258  20.114204  13.532852
# 2   4.293509  22.691579  -1.045155  -8.740350  12.401082  31.362987
# 3  -2.139348  23.158754 -26.241206  19.426465   9.472049   8.453948
# 4 -35.251034  27.281816 -29.470282 -21.786865  11.806822  58.655133
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_990  feature_991  \
# 0  -5.507209 -46.992476   5.175469 -47.768145  ...     7.815960    24.320965
# 1  34.298084  22.982509  37.938670 -35.648144  ...    11.145527   -38.886603
# 2 -18.831206 -35.384557   8.161430 -16.421762  ...    48.190331    -0.503157
# 3   0.637211 -26.675984 -43.823329  11.840874  ...   -51.613076    13.278858
# 4   5.375230  59.740676 -49.007717 -21.801155  ...     0.010857    20.975655
#
#    feature_992  feature_993  feature_994  feature_995  feature_996  \
# ...

# %%
pca_1=PCA(n_components=1)

# %%
pca_1.fit(df)
# Out:
# PCA(n_components=1)

# %%
sum(pca_1.explained_variance_ratio_)
# Out:
# np.float64(0.07898604806589325)

# %%
x_trans_1=pca_1.transform(df)

# %%
x_trans_1[:5]
# Out:
# array([[ 46.23564143],
#        [210.20875839],
#        [ 26.35279525],
#        [116.1068036 ],
#        [110.18360499]])

# %%
x_reduced_1=pca_1.inverse_transform(x_trans_1)

# %%
x_reduced_1[:5]
# Out:
# array([[ 6.18761684,  1.43672099, -8.39945313, ...,  4.80674979,
#         -3.80574689, -1.72505809],
#        [ 2.824463  ,  6.98992012, -7.02329405, ..., 13.42130605,
#         -1.03410163,  4.79388009],
#        [ 6.59542192,  0.76335815, -8.5663217 , ...,  3.76217675,
#         -4.14182756, -2.5155233 ],
#        [ 4.75453152,  3.80301422, -7.81305314, ...,  8.47752868,
#         -2.62471137,  1.05274961],
#        [ 4.87601868,  3.60241609, -7.86276411, ...,  8.16634519,
#         -2.72483147,  0.8172661 ]])

# %%
x_reduced_1.shape
# Out:
# (500, 1000)

# %%
variance=np.zeros(200)
for i in range(200):
    pca=PCA(n_components=i+1)
    df_fit=pca.fit(df)
    variance[i]=float(sum(pca.explained_variance_ratio_))

# %%
plt.plot(np.arange(1,201),variance,color='b')
